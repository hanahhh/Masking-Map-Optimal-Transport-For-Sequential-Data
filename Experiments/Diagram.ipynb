# %% [markdown]
# # 1. Turn result file into statistical diagram

# %%
import pandas as pd
df_original = pd.read_csv('../Results/finals/result.csv')
df = df_original.dropna().reset_index(drop=True)
df.head(30)
# Out:
#                       Unnamed: 0     GOW     DTW     OPW    TAOT    TCOT  \
# 0                      BeetleFly  0.6500  0.7000  1.0000  1.0000  1.0000
# 1                    BirdChicken  0.8500  0.7500  0.6000  0.5500  0.8500
# 2                         Coffee  0.9286  1.0000  1.0000  0.5714  0.8571
# 3    DistalPhalanxOutlineCorrect  0.7143  0.7571  0.6857  0.4286  0.6714
# 4                DistalPhalanxTW  0.7111  0.7444  0.7333  0.5000  0.7444
# 5                         ECG200  0.8700  0.8000  0.9000  0.9000  0.8400
# 6                       FaceFour  0.8000  0.7667  0.8000  0.5333  0.6333
# 7                       GunPoint  0.9933  0.9067  0.9133  0.8600  0.8333
# 8                        Herring  0.7000  0.5500  0.6500  0.7500  0.5500
# 9               ItalyPowerDemand  0.9456  0.9504  0.9563  0.9572  0.8358
# 10                    MoteStrain  0.8906  0.8347  0.7843  0.8562  0.7971
# 11                      OliveOil  0.9000  0.8667  0.9000  0.1667  0.6000
# 12                         Plane  1.0000  1.0000  0.9619  0.8476  1.0000
# 13              ToeSegmentation2  0.7778  0.8519  0.8148  0.8519  0.7407
# 14  DistalPhalanxOutlineAgeGroup  0.7500  0.7500  0.7300  0.4000  0.7300
# 15                          Wine  0.5370  0.5741  0.6111  0.5000  0.5741
# 16              SyntheticControl  0.8800  0.9900  0.9100  0.9200  0.5600
# 17             ProximalPhalanxTW  0.7900  0.7800  0.7800  0.4000  0.7700
# 18                    TwoLeadECG  0.8841  0.9043  0.7594  0.7006  0.9298
#
#        OTW     WSK   AWSWD  MMOT-subsq       WTK
# 0   1.0000  0.4500  1.0000    1.000000  0.950000
# 1   0.6000  0.2500  0.8500    0.950000  0.900000
# 2   0.9643  0.2500  1.0000    1.000000  1.000000
# 3   0.7143  0.3857  0.7429    0.770000  0.806667
# 4   0.7333  0.0111  0.7444    0.650000  0.795000
# 5   0.9100  0.6100  0.9100    0.940000  0.900000
# 6   0.7333  0.3333  0.8000    0.910000  0.954545
# 7   0.9533  0.4933  0.9867    0.970000  0.993333
# 8   0.7000  0.6500  0.5000    0.703125  0.625000
# 9   0.9621  0.4402  0.9552    0.970000  0.954325
# 10  0.8850  0.5495  0.9026    0.870000  0.884185
# 11  0.8667  0.1000  0.9000    0.900000  0.866667
# 12  0.9619  0.0000  1.0000    1.000000  1.000000
# 13  0.8148  0.4444  0.8519    0.930000  0.884615
# 14  0.7100  0.1900  0.7600    0.741007  0.850000
# 15  0.6481  0.5556  0.5370    0.722222  0.833333
# 16  0.8300  0.0000  0.8300    0.960000  0.996667
# 17  0.7700  0.0200  0.8100    0.814634  0.812500
# 18  0.7349  0.3951  0.9851    0.949956  0.992976

# %%
methods = [{"label": "DTW", "value": "DTW"}, {"label": "OPW", "value": "OPW"}, {"label": "TAOT", "value": "TAOT"}, {"label": "TCOT", "value": "TCOT"}, {"label": "OTW", "value": "OTW"}, {"label": "AWSWD", "value": "AWSWD"}, {"label": "MSOT", "value": "MMOT-subsq"}, {"label": "WTK", "value": "WTK"}]

# %%
columns = {"classifier_name": [], "dataset_name": [], "accuracy": []}
cd_diagram_df = pd.DataFrame(columns)

# %%
for index, row in df.iterrows():
  for method in methods:
    cd_diagram_df.loc[len(cd_diagram_df)] = {"classifier_name": row['Unnamed: 0'], "dataset_name": method['label'], "accuracy": row[method['value']]}
cd_diagram_df.to_csv('../Results/finals/data1.csv', index=False)

# %%
for method in methods:
    i=0
    for row in df[method['value']]:
        cd_diagram_df.loc[len(cd_diagram_df)] = {"classifier_name": method['value'], "dataset_name": df['Unnamed: 0'][i], "accuracy": row}
        i += 1
cd_diagram_df.to_csv('../Results/finals/data1.csv', index=False)

# %%
from critdd import Diagram
import pandas as pd

# %%
df = pd.read_csv('../Results/finals/data1.csv').pivot(
    index = "dataset_name",
    columns = "classifier_name",
    values = "accuracy"
)

# create a CD diagram from the Pandas DataFrame
diagram = Diagram(
    df.to_numpy(),
    treatment_names = df.columns,
    maximize_outcome = True
)

# inspect average ranks and groups of statistically indistinguishable treatments
diagram.average_ranks # the average rank of each treatment
diagram.get_groups(adjustment="holm")

# export the diagram to a file
diagram.to_file(
    "example.tex",
    # alpha = .05,
    adjustment = "holm",
    reverse_x = True,
    axis_options = {"title": "critdd"},
)
# Out:
# c:\Users\hoang\OneDrive\Documents\lab\Masking-Map-Optimal-Transport-For-Sequential-Data\venv\Lib\site-packages\scipy\stats\_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
